# %% [markdown]
# # 03 — Özellik mühendisliği
#
# TF-IDF vektörleştirme denemeleri.

# %%
import sys
sys.path.insert(0, '..')
from src.features.tfidf_vectorizer import TfidfFeatureBuilder

docs = ['data mining python', 'python sklearn']
b = TfidfFeatureBuilder({'max_features': 100, 'ngram_range': (1, 2)})
X = b.fit_transform(docs)
print(X.shape)
