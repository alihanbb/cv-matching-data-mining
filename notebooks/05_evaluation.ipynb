# %% [markdown]
# # 05 — Değerlendirme
#
# Ground truth CSV ile Top-K ve precision@K.

# %%
import pandas as pd
from pathlib import Path

ranked = pd.read_csv(Path('..') / 'data/gold/rankings/candidate_scores.csv')
ranked.head()
