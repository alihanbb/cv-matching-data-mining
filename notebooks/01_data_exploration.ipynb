# %% [markdown]
# # 01 — Veri keşfi
#
# Ham ve işlenmiş CSV'leri yükleyip özet istatistikler.

# %%
import pandas as pd
from pathlib import Path

root = Path('..')
cvs = pd.read_csv(root / 'data/silver/cleaned_cvs.csv')
jobs = pd.read_csv(root / 'data/silver/cleaned_jobs.csv')
display(cvs.head(), jobs.head())
