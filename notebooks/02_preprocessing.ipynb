# %% [markdown]
# # 02 — Ön işleme
#
# `TextCleaner` ile metin normalizasyonu.

# %%
import sys
sys.path.insert(0, '..')
from src.preprocessing.cleaner import TextCleaner

c = TextCleaner()
print(c.clean('Hello World! NLP and Python 3.10.'))
